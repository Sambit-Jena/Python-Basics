# %% [markdown]
# ### TASK-2

# %%
import pandas as pd
PORTFOLIO_PERF_DATA_2022 = pd.read_excel(r'C:\Users\SAMBIT KUMAR\Downloads\A5.ASSIGNMENTS-20240403T050442Z-001\A5.ASSIGNMENTS\DATA\ACCOUNT_PERF_DATA.xlsx', sheet_name='ACCOUNT_PERFORMANCE_DATA')

# %%
PORTFOLIO_PERF_DATA_2022
# Out:
#        Account_number      PORTFOLIO          SSN    Phone No.   \
# 0            38673575    CREDIT CARD  640-29-9264  405-775-9884
# 1            38673576  PERSONAL LOAN  375-37-8517  212-786-7533
# 2            38673577  PERSONAL LOAN  073-02-5563  385-775-0225
# 3            38673578       MORTGAGE  106-98-7919  216-984-8974
# 4            38673579    CREDIT CARD  753-07-4655  217-307-8597
# ...               ...            ...          ...           ...
# 24999        38698574    CREDIT CARD  112-98-5765  201-857-6904
# 25000        38698575  PERSONAL LOAN  507-57-2035  209-410-5762
# 25001        38698576       MORTGAGE  094-02-7375  212-698-6318
# 25002        38698577  PERSONAL LOAN  467-99-0614  212-525-5734
# 25003        38698578       MORTGAGE  191-86-1363  229-974-6770
#
#            Place Name      County            City State    Zip     Region  \
# 0             Bromide    Johnston         Bromide    OK  74530      South
# ...

# %%
PORTFOLIO_PERF_DATA_2022.head(100)
# Out:
#     Account_number      PORTFOLIO          SSN    Phone No.       Place Name  \
# 0         38673575    CREDIT CARD  640-29-9264  405-775-9884         Bromide
# 1         38673576  PERSONAL LOAN  375-37-8517  212-786-7533  Reading Center
# 2         38673577  PERSONAL LOAN  073-02-5563  385-775-0225          Ibapah
# 3         38673578       MORTGAGE  106-98-7919  216-984-8974       Wickliffe
# 4         38673579    CREDIT CARD  753-07-4655  217-307-8597         Forrest
# ..             ...            ...          ...           ...             ...
# 95        38673670    CREDIT CARD  119-98-5733  215-753-6443    Conshohocken
# 96        38673671    CREDIT CARD  510-33-2272  209-685-5524         Klamath
# 97        38673672    CREDIT CARD  168-86-4252  303-439-4051     Westminster
# 98        38673673    CREDIT CARD  730-28-5224  302-854-2835         Yorklyn
# 99        38673674  PERSONAL LOAN  381-37-7296  210-580-0080     San Antonio
#
# ...

# %%
PORTFOLIO_PERF_DATA_2022.tail(100)
# Out:
#        Account_number      PORTFOLIO          SSN    Phone No.    Place Name  \
# 24904        38698479    CREDIT CARD  092-02-0144  803-448-0539        Lando
# 24905        38698480       MORTGAGE  673-48-6681  314-448-4803        Briar
# 24906        38698481       MORTGAGE  127-98-1326  205-604-2328  Hazel Green
# 24907        38698482    CREDIT CARD  540-83-0348  201-848-6649      Absecon
# 24908        38698483       MORTGAGE  069-02-1613  210-994-6664    Arlington
# ...               ...            ...          ...           ...          ...
# 24999        38698574    CREDIT CARD  112-98-5765  201-857-6904      Wenonah
# 25000        38698575  PERSONAL LOAN  507-57-2035  209-410-5762   West Point
# 25001        38698576       MORTGAGE  094-02-7375  212-698-6318     Syracuse
# 25002        38698577  PERSONAL LOAN  467-99-0614  212-525-5734     Woodbury
# 25003        38698578       MORTGAGE  191-86-1363  229-974-6770    Grovetown
#
# ...

# %%
TOP_100=PORTFOLIO_PERF_DATA_2022.head(100)
LAST_100=PORTFOLIO_PERF_DATA_2022.tail(100)

# %%
# Display the top 100 records
print("Top 100 records:")
print(TOP_100)
# Display the bottom 100 records
print("\nBottom 100 records:")
print(LAST_100)
# Out:
# Top 100 records:
#     Account_number      PORTFOLIO          SSN    Phone No.       Place Name  \
# 0         38673575    CREDIT CARD  640-29-9264  405-775-9884         Bromide
# 1         38673576  PERSONAL LOAN  375-37-8517  212-786-7533  Reading Center
# 2         38673577  PERSONAL LOAN  073-02-5563  385-775-0225          Ibapah
# 3         38673578       MORTGAGE  106-98-7919  216-984-8974       Wickliffe
# 4         38673579    CREDIT CARD  753-07-4655  217-307-8597         Forrest
# ..             ...            ...          ...           ...             ...
# 95        38673670    CREDIT CARD  119-98-5733  215-753-6443    Conshohocken
# 96        38673671    CREDIT CARD  510-33-2272  209-685-5524         Klamath
# 97        38673672    CREDIT CARD  168-86-4252  303-439-4051     Westminster
# 98        38673673    CREDIT CARD  730-28-5224  302-854-2835         Yorklyn
# 99        38673674  PERSONAL LOAN  381-37-7296  210-580-0080     San Antonio
#
# ...

# %%
PORTFOLIO_PERF_DATA_2022.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25004 entries, 0 to 25003
# Data columns (total 17 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Account_number          25004 non-null  int64
#  1   PORTFOLIO               25004 non-null  object
#  2   SSN                     25004 non-null  object
#  3   Phone No.               24879 non-null  object
#  4   Place Name              24989 non-null  object
#  5   County                  25004 non-null  object
#  6   City                    24993 non-null  object
#  7   State                   25004 non-null  object
#  8   Zip                     25004 non-null  int64
#  9   Region                  24991 non-null  object
#  10  Account Open Date       25004 non-null  datetime64[ns]
#  11  Loan_amount             25004 non-null  int64
#  12  Loan_status             24998 non-null  object
#  13  Last_payment_date       24987 non-null  datetime64[ns]
# ...

# %%
PORTFOLIO_PERF_DATA_2022.dtypes
# Out:
# Account_number                     int64
# PORTFOLIO                         object
# SSN                               object
# Phone No.                         object
# Place Name                        object
# County                            object
# City                              object
# State                             object
# Zip                                int64
# Region                            object
# Account Open Date         datetime64[ns]
# Loan_amount                        int64
# Loan_status                       object
# Last_payment_date         datetime64[ns]
# Origination_fico_score             int64
# Current_fico_score                 int64
# Current_outstanding              float64
# dtype: object

# %%
columns_list=PORTFOLIO_PERF_DATA_2022.columns
columns_list
# Out:
# Index(['Account_number', 'PORTFOLIO', 'SSN', 'Phone No. ', 'Place Name',
#        'County', 'City', 'State', 'Zip', 'Region', 'Account Open Date',
#        'Loan_amount', 'Loan_status', 'Last_payment_date',
#        'Origination_fico_score', 'Current_fico_score', 'Current_outstanding'],
#       dtype='object')

# %%
for i in PORTFOLIO_PERF_DATA_2022.columns:
    counts = PORTFOLIO_PERF_DATA_2022[i].value_counts()
    print(f"Count of records by {i}:")
    print(counts)
    print()
# Out:
# Count of records by Account_number:
# 38674436    1
# 38677839    1
# 38673769    1
# 38694247    1
# 38692198    1
#            ..
# 38691513    1
# 38693560    1
# 38679219    1
# 38681266    1
# 38674428    1
# Name: Account_number, Length: 25004, dtype: int64
#
# Count of records by PORTFOLIO:
# CREDIT CARD      10180
# MORTGAGE          9788
# PERSONAL LOAN     5036
# Name: PORTFOLIO, dtype: int64
#
# Count of records by SSN:
# 160-86-4471    2
# 076-02-4817    2
# 572-99-2274    2
# 085-02-0788    2
# 212-91-4515    2
#               ..
# 629-31-9710    1
# 102-02-6768    1
# 503-45-3940    1
# 586-67-7828    1
# 078-02-0484    1
# Name: SSN, Length: 24985, dtype: int64
#
# Count of records by Phone No. :
# 215-541-4438    1
# 339-470-1115    1
# 236-890-4006    1
# 503-918-5294    1
# 339-976-0098    1
#                ..
# 210-651-1972    1
# 505-645-3006    1
# 385-377-9088    1
# 505-295-0328    1
# 201-930-6085    1
# Name: Phone No. , Length: 24879, dtype: int64
#
# ...

# %%
PORTFOLIO_PERF_DATA_2022.isnull().sum()
# Out:
# Account_number              0
# PORTFOLIO                   0
# SSN                         0
# Phone No.                 125
# Place Name                 15
# County                      0
# City                       11
# State                       0
# Zip                         0
# Region                     13
# Account Open Date           0
# Loan_amount                 0
# Loan_status                 6
# Last_payment_date          17
# Origination_fico_score      0
# Current_fico_score          0
# Current_outstanding        14
# dtype: int64

# %%
PORTFOLIO_PERF_DATA_2022.isnull().sum().sum()
# Out:
# 201

# %%
PORTFOLIO_PERF_DATA_2022_V1=PORTFOLIO_PERF_DATA_2022[['Account_number','PORTFOLIO','SSN','Phone No. ','Region','Account Open Date','Loan_amount','Loan_status','Current_fico_score','Current_outstanding']]

# %%
PORTFOLIO_PERF_DATA_2022_V1
# Out:
#        Account_number      PORTFOLIO          SSN    Phone No.      Region  \
# 0            38673575    CREDIT CARD  640-29-9264  405-775-9884      South
# 1            38673576  PERSONAL LOAN  375-37-8517  212-786-7533  Northeast
# 2            38673577  PERSONAL LOAN  073-02-5563  385-775-0225       West
# 3            38673578       MORTGAGE  106-98-7919  216-984-8974    Midwest
# 4            38673579    CREDIT CARD  753-07-4655  217-307-8597    Midwest
# ...               ...            ...          ...           ...        ...
# 24999        38698574    CREDIT CARD  112-98-5765  201-857-6904  Northeast
# 25000        38698575  PERSONAL LOAN  507-57-2035  209-410-5762       West
# 25001        38698576       MORTGAGE  094-02-7375  212-698-6318  Northeast
# 25002        38698577  PERSONAL LOAN  467-99-0614  212-525-5734  Northeast
# 25003        38698578       MORTGAGE  191-86-1363  229-974-6770      South
#
# ...

# %%
PORTFOLIO_PERF_DATA_2022_V2=PORTFOLIO_PERF_DATA_2022.drop(['Place Name','County','City','Zip','Region','Last_payment_date','Origination_fico_score'],axis=1)

# %%
PORTFOLIO_PERF_DATA_2022_V2
# Out:
#        Account_number      PORTFOLIO          SSN    Phone No.  State  \
# 0            38673575    CREDIT CARD  640-29-9264  405-775-9884    OK
# 1            38673576  PERSONAL LOAN  375-37-8517  212-786-7533    NY
# 2            38673577  PERSONAL LOAN  073-02-5563  385-775-0225    UT
# 3            38673578       MORTGAGE  106-98-7919  216-984-8974    OH
# 4            38673579    CREDIT CARD  753-07-4655  217-307-8597    IL
# ...               ...            ...          ...           ...   ...
# 24999        38698574    CREDIT CARD  112-98-5765  201-857-6904    NJ
# 25000        38698575  PERSONAL LOAN  507-57-2035  209-410-5762    CA
# 25001        38698576       MORTGAGE  094-02-7375  212-698-6318    NY
# 25002        38698577  PERSONAL LOAN  467-99-0614  212-525-5734    NY
# 25003        38698578       MORTGAGE  191-86-1363  229-974-6770    GA
#
#       Account Open Date  Loan_amount  Loan_status  Current_fico_score  \
# ...

# %%
PORTFOLIO_PERF_DATA_2022_V3=PORTFOLIO_PERF_DATA_2022.sort_values(by=['PORTFOLIO','County','Loan_amount'],ascending=[True,True,False])

# %%
PORTFOLIO_PERF_DATA_2022_V3
# Out:
#        Account_number      PORTFOLIO          SSN    Phone No.     Place Name  \
# 9284         38682859    CREDIT CARD  193-86-6768  225-470-7371          Egan
# 15292        38688867    CREDIT CARD  011-94-5325  225-531-9221         Morse
# 6165         38679740    CREDIT CARD  576-99-6311  225-317-4900    Evangeline
# 16959        38690534    CREDIT CARD  441-29-5924  236-246-2777     Harborton
# 24752        38698327    CREDIT CARD  125-98-2051  236-390-0985      Atlantic
# ...               ...            ...          ...           ...           ...
# 4727         38678302  PERSONAL LOAN  489-29-8576  907-294-4625        Tanana
# 20078        38693653  PERSONAL LOAN  700-18-3484  480-829-8984          Yuma
# 14258        38687833  PERSONAL LOAN  190-86-6009  605-948-7925         Zeona
# 20638        38694213  PERSONAL LOAN  098-02-6979  605-466-9739  Cherry Creek
# 22850        38696425  PERSONAL LOAN  657-36-9250  605-909-1927  Cherry Creek
#
# ...

# %%
CREDIT_CARD=PORTFOLIO_PERF_DATA_2022[(PORTFOLIO_PERF_DATA_2022['PORTFOLIO']=='CREDIT CARD')]

# %%
CREDIT_CARD
# Out:
#        Account_number    PORTFOLIO          SSN    Phone No.    Place Name  \
# 0            38673575  CREDIT CARD  640-29-9264  405-775-9884      Bromide
# 4            38673579  CREDIT CARD  753-07-4655  217-307-8597      Forrest
# 6            38673581  CREDIT CARD  090-02-6498  339-289-4655       Newton
# 8            38673583  CREDIT CARD  276-17-0083  209-252-3832  Pico Rivera
# 12           38673587  CREDIT CARD  556-99-2038  339-922-2190     Pembroke
# ...               ...          ...          ...           ...          ...
# 24983        38698558  CREDIT CARD  579-53-4759  218-645-6825       Watson
# 24987        38698562  CREDIT CARD  539-71-5515  219-506-1015  Bloomington
# 24990        38698565  CREDIT CARD  721-18-1919  206-717-5311  Leavenworth
# 24993        38698568  CREDIT CARD  406-73-7119  210-227-8906        Simms
# 24999        38698574  CREDIT CARD  112-98-5765  201-857-6904      Wenonah
#
# ...

# %%
PERSONAL_LOAN=PORTFOLIO_PERF_DATA_2022[(PORTFOLIO_PERF_DATA_2022['PORTFOLIO']=='PERSONAL LOAN')]

# %%
PERSONAL_LOAN
# Out:
#        Account_number      PORTFOLIO          SSN    Phone No.   \
# 1            38673576  PERSONAL LOAN  375-37-8517  212-786-7533
# 2            38673577  PERSONAL LOAN  073-02-5563  385-775-0225
# 7            38673582  PERSONAL LOAN  390-33-0765  218-314-7370
# 15           38673590  PERSONAL LOAN  233-57-1697  219-545-4790
# 16           38673591  PERSONAL LOAN  668-48-6539  314-754-2773
# ...               ...            ...          ...           ...
# 24981        38698556  PERSONAL LOAN  492-29-1690  304-457-9114
# 24992        38698567  PERSONAL LOAN  016-94-9378  303-873-8569
# 24994        38698569  PERSONAL LOAN  596-94-1180  209-366-9348
# 25000        38698575  PERSONAL LOAN  507-57-2035  209-410-5762
# 25002        38698577  PERSONAL LOAN  467-99-0614  212-525-5734
#
#            Place Name     County            City State    Zip     Region  \
# 1      Reading Center   Schuyler  Reading Center    NY  14876  Northeast
# ...

# %%
MORTGAGE=PORTFOLIO_PERF_DATA_2022[(PORTFOLIO_PERF_DATA_2022['PORTFOLIO']=='MORTGAGE')]

# %%
MORTGAGE
# Out:
#        Account_number PORTFOLIO          SSN    Phone No.       Place Name  \
# 3            38673578  MORTGAGE  106-98-7919  216-984-8974       Wickliffe
# 5            38673580  MORTGAGE  770-02-0049  201-312-1614  Highland Lakes
# 9            38673584  MORTGAGE  677-22-7228  307-872-6444          Casper
# 10           38673585  MORTGAGE  149-23-6087  479-493-2345       Van Buren
# 11           38673586  MORTGAGE  211-84-1802  319-658-2317         Moville
# ...               ...       ...          ...           ...             ...
# 24996        38698571  MORTGAGE  482-41-8559  215-432-2028          Warren
# 24997        38698572  MORTGAGE  725-18-5262  239-778-5164          Deland
# 24998        38698573  MORTGAGE  500-29-4129  218-634-3018        Foreston
# 25001        38698576  MORTGAGE  094-02-7375  212-698-6318        Syracuse
# 25003        38698578  MORTGAGE  191-86-1363  229-974-6770       Grovetown
#
# ...

# %% [markdown]
# ## TASK-3

# %%
PORTFOLIO_DATA=pd.read_excel('ACCOUNT_PERF_DATA.xlsx')

# %%
PORTFOLIO_DATA
# Out:
#        Account_number      PORTFOLIO          SSN    Phone No.   \
# 0            38673575    CREDIT CARD  640-29-9264  405-775-9884
# 1            38673576  PERSONAL LOAN  375-37-8517  212-786-7533
# 2            38673577  PERSONAL LOAN  073-02-5563  385-775-0225
# 3            38673578       MORTGAGE  106-98-7919  216-984-8974
# 4            38673579    CREDIT CARD  753-07-4655  217-307-8597
# ...               ...            ...          ...           ...
# 24999        38698574    CREDIT CARD  112-98-5765  201-857-6904
# 25000        38698575  PERSONAL LOAN  507-57-2035  209-410-5762
# 25001        38698576       MORTGAGE  094-02-7375  212-698-6318
# 25002        38698577  PERSONAL LOAN  467-99-0614  212-525-5734
# 25003        38698578       MORTGAGE  191-86-1363  229-974-6770
#
#            Place Name      County            City State    Zip     Region  \
# 0             Bromide    Johnston         Bromide    OK  74530      South
# ...

# %%
NY_CREDIT_CARD_SOUTH_REGION = PORTFOLIO_DATA[
    (PORTFOLIO_DATA['PORTFOLIO'] == 'CREDIT CARD') &
    (PORTFOLIO_DATA['State'] == 'NY') &
    (PORTFOLIO_DATA['Region'] == 'SOUTH') &
    (PORTFOLIO_DATA['Loan_status'] == 'DEFAULT') &
    (PORTFOLIO_DATA['Current_outstanding'].between(10000, 30000, inclusive=True))
]

# %%
NY_CREDIT_CARD_SOUTH_REGION
# Out:
# Empty DataFrame
# Columns: [Account_number, PORTFOLIO, SSN, Phone No. , Place Name, County, City, State, Zip, Region, Account Open Date, Loan_amount, Loan_status, Last_payment_date, Origination_fico_score, Current_fico_score, Current_outstanding]
# Index: []

# %%
PORTFOLIO_DATA_SUMMARY = PORTFOLIO_DATA.groupby(
    ['State', 'PORTFOLIO', 'Loan_status'],
    as_index=True
).agg(
    NUMBER_OF_ACCOUNTS=('Account_number', 'count'),
    TOTAL_LOAN_AMOUNT=('Loan_amount', 'sum'),
    TOTAL_OUTSTANDING=('Current_outstanding', 'sum')
)

# %%
PORTFOLIO_DATA_SUMMARY
# Out:
#                                  NUMBER_OF_ACCOUNTS  TOTAL_LOAN_AMOUNT  \
# State PORTFOLIO     Loan_status
# AK    CREDIT CARD   Default                      16             964129
#                     Non-Default                  41            2641685
#       MORTGAGE      Default                      20           11235393
#                     Non-Default                  44           23109130
#       PERSONAL LOAN Default                      13            1332221
# ...                                             ...                ...
# WY    CREDIT CARD   Non-Default                  35            2167758
#       MORTGAGE      Default                       8            3411185
#                     Non-Default                  32           15112644
#       PERSONAL LOAN Default                       4             548174
#                     Non-Default                  13            1531118
#
#                                  TOTAL_OUTSTANDING
# ...

# %%
unique_portfolios = PORTFOLIO_DATA['PORTFOLIO'].unique()
unique_counties = PORTFOLIO_DATA['County'].unique()
unique_states = PORTFOLIO_DATA['State'].unique()

# %%
unique_portfolios
# Out:
# array(['CREDIT CARD', 'PERSONAL LOAN', 'MORTGAGE'], dtype=object)

# %%
unique_counties
# Out:
# array(['Johnston', 'Schuyler', 'Tooele', ..., 'Heard', 'Meagher',
#        'Archuleta'], dtype=object)

# %%
unique_states
# Out:
# array(['OK', 'NY', 'UT', 'OH', 'IL', 'NJ', 'MA', 'MN', 'CA', 'WY', 'AR',
#        'IA', 'MI', 'MO', 'IN', 'FL', 'TX', 'ID', 'NE', 'OR', 'AL', 'TN',
#        'PA', 'MT', 'KY', 'WI', 'WV', 'MS', 'MD', 'GA', 'AZ', 'AK', 'ME',
#        'NV', 'LA', 'KS', 'CO', 'HI', 'SC', 'WA', 'DE', 'NC', 'VT', 'NM',
#        'VA', 'DC', 'SD', 'CT', 'ND', 'NH', 'RI'], dtype=object)

# %%
PORTFOLIO_DATA['TOTAL_PAID_AMOUNT'] = PORTFOLIO_DATA['Loan_amount'] - PORTFOLIO_DATA['Current_outstanding']
PORTFOLIO_DATA['TOTAL_PAID_AMOUNT'] = PORTFOLIO_DATA['TOTAL_PAID_AMOUNT'].apply(lambda x: '${:,.0f}'.format(x))

# %%
PORTFOLIO_DATA
# Out:
#        Account_number      PORTFOLIO          SSN    Phone No.   \
# 0            38673575    CREDIT CARD  640-29-9264  405-775-9884
# 1            38673576  PERSONAL LOAN  375-37-8517  212-786-7533
# 2            38673577  PERSONAL LOAN  073-02-5563  385-775-0225
# 3            38673578       MORTGAGE  106-98-7919  216-984-8974
# 4            38673579    CREDIT CARD  753-07-4655  217-307-8597
# ...               ...            ...          ...           ...
# 24999        38698574    CREDIT CARD  112-98-5765  201-857-6904
# 25000        38698575  PERSONAL LOAN  507-57-2035  209-410-5762
# 25001        38698576       MORTGAGE  094-02-7375  212-698-6318
# 25002        38698577  PERSONAL LOAN  467-99-0614  212-525-5734
# 25003        38698578       MORTGAGE  191-86-1363  229-974-6770
#
#            Place Name      County            City State    Zip     Region  \
# 0             Bromide    Johnston         Bromide    OK  74530      South
# ...

# %%
PORTFOLIO_DATA['BALANCE_PERCENTAGE'] = (PORTFOLIO_DATA['Current_outstanding']/PORTFOLIO_DATA['Loan_amount'])*100

# %%
PORTFOLIO_DATA
# Out:
#        Account_number      PORTFOLIO          SSN    Phone No.   \
# 0            38673575    CREDIT CARD  640-29-9264  405-775-9884
# 1            38673576  PERSONAL LOAN  375-37-8517  212-786-7533
# 2            38673577  PERSONAL LOAN  073-02-5563  385-775-0225
# 3            38673578       MORTGAGE  106-98-7919  216-984-8974
# 4            38673579    CREDIT CARD  753-07-4655  217-307-8597
# ...               ...            ...          ...           ...
# 24999        38698574    CREDIT CARD  112-98-5765  201-857-6904
# 25000        38698575  PERSONAL LOAN  507-57-2035  209-410-5762
# 25001        38698576       MORTGAGE  094-02-7375  212-698-6318
# 25002        38698577  PERSONAL LOAN  467-99-0614  212-525-5734
# 25003        38698578       MORTGAGE  191-86-1363  229-974-6770
#
#            Place Name      County            City State    Zip     Region  \
# 0             Bromide    Johnston         Bromide    OK  74530      South
# ...

# %%
def RISK_SEGMENT(BALANCE_PERCENTAGE):
    if BALANCE_PERCENTAGE >= 50:
        return 'CRITICAL'
    elif 30 <= BALANCE_PERCENTAGE < 50:
        return 'HIGH RISK'
    elif 20 <= BALANCE_PERCENTAGE < 30:
        return 'MID RISK'
    else:
        return 'LOW RISK'

# %%
RISK_SEGMENT(70)
# Out:
# 'CRITICAL'

# %%
PORTFOLIO_DATA['RISK_SEGMENT']=PORTFOLIO_DATA['BALANCE_PERCENTAGE'].apply(RISK_SEGMENT)
PORTFOLIO_DATA
# Out:
#        Account_number      PORTFOLIO          SSN    Phone No.   \
# 0            38673575    CREDIT CARD  640-29-9264  405-775-9884
# 1            38673576  PERSONAL LOAN  375-37-8517  212-786-7533
# 2            38673577  PERSONAL LOAN  073-02-5563  385-775-0225
# 3            38673578       MORTGAGE  106-98-7919  216-984-8974
# 4            38673579    CREDIT CARD  753-07-4655  217-307-8597
# ...               ...            ...          ...           ...
# 24999        38698574    CREDIT CARD  112-98-5765  201-857-6904
# 25000        38698575  PERSONAL LOAN  507-57-2035  209-410-5762
# 25001        38698576       MORTGAGE  094-02-7375  212-698-6318
# 25002        38698577  PERSONAL LOAN  467-99-0614  212-525-5734
# 25003        38698578       MORTGAGE  191-86-1363  229-974-6770
#
#            Place Name      County            City State    Zip     Region  \
# 0             Bromide    Johnston         Bromide    OK  74530      South
# ...

# %%
PORTFOLIO_DATA['BALANCE_PERCENTAGE'] = PORTFOLIO_DATA['BALANCE_PERCENTAGE'].apply(lambda x: f"{x:.0f}%")

# %%
PORTFOLIO_DATA
# Out:
#        Account_number      PORTFOLIO          SSN    Phone No.   \
# 0            38673575    CREDIT CARD  640-29-9264  405-775-9884
# 1            38673576  PERSONAL LOAN  375-37-8517  212-786-7533
# 2            38673577  PERSONAL LOAN  073-02-5563  385-775-0225
# 3            38673578       MORTGAGE  106-98-7919  216-984-8974
# 4            38673579    CREDIT CARD  753-07-4655  217-307-8597
# ...               ...            ...          ...           ...
# 24999        38698574    CREDIT CARD  112-98-5765  201-857-6904
# 25000        38698575  PERSONAL LOAN  507-57-2035  209-410-5762
# 25001        38698576       MORTGAGE  094-02-7375  212-698-6318
# 25002        38698577  PERSONAL LOAN  467-99-0614  212-525-5734
# 25003        38698578       MORTGAGE  191-86-1363  229-974-6770
#
#            Place Name      County            City State    Zip     Region  \
# 0             Bromide    Johnston         Bromide    OK  74530      South
# ...

# %% [markdown]
# ### TASK - 4

# %%
import pandas as pd

file_path = r'C:\Users\SAMBIT KUMAR\Downloads\A5.ASSIGNMENTS-20240403T050442Z-001\A5.ASSIGNMENTS\PYTHON SESSION-2 ASSIGNMENTS.xlsx'
MED_SELECT = pd.read_excel(file_path, sheet_name='MED_DATA')

# %%
MED_SELECT
# Out:
#       CUSTOMER_ID    Company CARD_REG_DATE  GENDER  Age RGSTN_TYPE_IND  \
# 0      1000032547      MED +    2006-09-12  Female   36         Online
# 1      1000032548  DR.REDDYS    2006-09-12  Female   47         Online
# 2      1000032549   RELEGARE    2006-09-12  Female   62         Online
# 3      1000032550        GSK    2006-09-12    Male   43         Online
# 4      1000032551        GSK    2006-09-12    Male   42         Online
# ...           ...        ...           ...     ...  ...            ...
# 5107   1000037830   RELEGARE    2008-05-06    Male   85         Online
# 5108   1000037831     APPOLO    2008-05-06  Female   65         Online
# 5109   1000037832        GSK    2008-05-06  Female   39          Phone
# 5110   1000037833      MED +    2008-05-06  Female   61         Online
# 5111   1000037834    RANBAXY    2008-05-06  Female   49     Instore/RF
#
#      STATE_CODE  NO_OF_TRIPS           TOWN CONTACT_PREF  Spent amount
# ...

# %%
def AGE_BUCKET(Age):
    if Age < 30:
        return 'Less than 30'
    elif Age >= 30 and Age <= 50:
        return '30 to 50'
    elif Age >= 51 and Age <= 70:
        return '51 to 70'
    else:
        return '70+'

# %%
MED_SELECT['AGE_BUCKET']=MED_SELECT['Age'].apply(AGE_BUCKET)

# %%
MED_SELECT
# Out:
#       CUSTOMER_ID    Company CARD_REG_DATE  GENDER  Age RGSTN_TYPE_IND  \
# 0      1000032547      MED +    2006-09-12  Female   36         Online
# 1      1000032548  DR.REDDYS    2006-09-12  Female   47         Online
# 2      1000032549   RELEGARE    2006-09-12  Female   62         Online
# 3      1000032550        GSK    2006-09-12    Male   43         Online
# 4      1000032551        GSK    2006-09-12    Male   42         Online
# ...           ...        ...           ...     ...  ...            ...
# 5107   1000037830   RELEGARE    2008-05-06    Male   85         Online
# 5108   1000037831     APPOLO    2008-05-06  Female   65         Online
# 5109   1000037832        GSK    2008-05-06  Female   39          Phone
# 5110   1000037833      MED +    2008-05-06  Female   61         Online
# 5111   1000037834    RANBAXY    2008-05-06  Female   49     Instore/RF
#
#      STATE_CODE  NO_OF_TRIPS           TOWN CONTACT_PREF  Spent amount  \
# ...

# %%
def SPENT_BUCKET (Spent_amount):
    if Spent_amount < 300:
        return 'Less than 300'
    elif Spent_amount >= 301 and Spent_amount <= 500:
        return '301 to 500'
    elif Spent_amount >= 501 and Spent_amount <= 700:
        return '501 to 700'
    elif Spent_amount >= 701 and Spent_amount <= 1000:
        return '701 to 1000'
    else:
        return '1000+'

# %%
MED_SELECT['SPENT_BUCKET']=MED_SELECT['Spent amount'].apply(SPENT_BUCKET)

# %%
MED_SELECT_V6 = MED_SELECT

# %%
MED_SELECT_V6
# Out:
#       CUSTOMER_ID    Company CARD_REG_DATE  GENDER  Age RGSTN_TYPE_IND  \
# 0      1000032547      MED +    2006-09-12  Female   36         Online
# 1      1000032548  DR.REDDYS    2006-09-12  Female   47         Online
# 2      1000032549   RELEGARE    2006-09-12  Female   62         Online
# 3      1000032550        GSK    2006-09-12    Male   43         Online
# 4      1000032551        GSK    2006-09-12    Male   42         Online
# ...           ...        ...           ...     ...  ...            ...
# 5107   1000037830   RELEGARE    2008-05-06    Male   85         Online
# 5108   1000037831     APPOLO    2008-05-06  Female   65         Online
# 5109   1000037832        GSK    2008-05-06  Female   39          Phone
# 5110   1000037833      MED +    2008-05-06  Female   61         Online
# 5111   1000037834    RANBAXY    2008-05-06  Female   49     Instore/RF
#
#      STATE_CODE  NO_OF_TRIPS           TOWN CONTACT_PREF  Spent amount  \
# ...

# %%
def CUSTOMER_SEGMENT(row):
    Age = row['Age']
    GENDER = row['GENDER']
    Spent_amount = row['Spent amount']
    
    if 30 <= Age <= 70 and Spent_amount >= 300:
        if GENDER == 'Female':
            return 'PREMIER'
        elif GENDER == 'Male':
            return 'PREMIER'
    return 'NON-PREMIER'

MED_SELECT_V6['CUSTOMER_SEGMENT'] = MED_SELECT_V6[['Age', 'GENDER', 'Spent amount']].apply(CUSTOMER_SEGMENT, axis=1)

# %%
MED_SELECT_V6
# Out:
#       CUSTOMER_ID    Company CARD_REG_DATE  GENDER  Age RGSTN_TYPE_IND  \
# 0      1000032547      MED +    2006-09-12  Female   36         Online
# 1      1000032548  DR.REDDYS    2006-09-12  Female   47         Online
# 2      1000032549   RELEGARE    2006-09-12  Female   62         Online
# 3      1000032550        GSK    2006-09-12    Male   43         Online
# 4      1000032551        GSK    2006-09-12    Male   42         Online
# ...           ...        ...           ...     ...  ...            ...
# 5107   1000037830   RELEGARE    2008-05-06    Male   85         Online
# 5108   1000037831     APPOLO    2008-05-06  Female   65         Online
# 5109   1000037832        GSK    2008-05-06  Female   39          Phone
# 5110   1000037833      MED +    2008-05-06  Female   61         Online
# 5111   1000037834    RANBAXY    2008-05-06  Female   49     Instore/RF
#
#      STATE_CODE  NO_OF_TRIPS           TOWN CONTACT_PREF  Spent amount  \
# ...

# %%
SUBS=MED_SELECT_V6['CUSTOMER_ID']. count()
VISITS=MED_SELECT_V6['NO_OF_TRIPS']. sum()
TOTAL_SPENT=MED_SELECT_V6['Spent amount']. sum()

# %%
t={'SUBS':[SUBS],'VISITS':[VISITS],'TOTAL_SPENT':[TOTAL_SPENT]}

# %%
MED_AGG=pd.DataFrame(t)
MED_AGG['TOTAL_SPENT']=MED_AGG['TOTAL_SPENT'].apply(lambda x: f"${x:,.0f}")

# %%
MED_AGG
# Out:
#    SUBS  VISITS TOTAL_SPENT
# 0  5112   27139  $1,656,881

# %%
MED_AGG2=MED_SELECT_V6.groupby(['Company'], as_index=True).agg(SUBS=('CUSTOMER_ID', 'count'), VISITS=('NO_OF_TRIPS','sum'),TOTAL_SPENT=('Spent amount','sum'))
MED_AGG2['TOTAL_SPENT']=MED_AGG2['TOTAL_SPENT'].apply(lambda x: f"${x:,.0f}")

# %%
MED_AGG2
# Out:
#            SUBS  VISITS TOTAL_SPENT
# Company
# APPOLO      580    3154    $190,592
# CIPLA       571    2943    $178,281
# DR.REDDYS   576    3326    $195,328
# GENO        571    2737    $162,880
# GSK         602    3395    $200,580
# GUARDIAN    547    2979    $186,094
# MED +       584    3060    $190,843
# RANBAXY     529    2839    $172,572
# RELEGARE    552    2706    $179,710

# %%
MED_AGG3=MED_SELECT_V6.groupby(['Company','GENDER'], as_index=True).agg(SUBS=('CUSTOMER_ID', 'count'), VISITS=('NO_OF_TRIPS','sum'),TOTAL_SPENT=('Spent amount','sum'))
MED_AGG3['TOTAL_SPENT']=MED_AGG3['TOTAL_SPENT'].apply(lambda x: f"${x:,.0f}")
MED_AGG3
# Out:
#                   SUBS  VISITS TOTAL_SPENT
# Company   GENDER
# APPOLO    Female   388    2174    $131,270
#           Male     189     921     $56,645
#           Unisex     3      59      $2,677
# CIPLA     Female   369    1955    $120,123
#           Male     197     955     $55,504
#           Unisex     5      33      $2,655
# DR.REDDYS Female   367    2133    $130,479
#           Male     208    1191     $64,681
#           Unisex     1       2        $168
# GENO      Female   384    1814    $109,583
#           Male     186     921     $53,253
#           Unisex     1       2         $44
# GSK       Female   402    2307    $133,569
#           Male     196    1065     $65,863
#           Unisex     4      23      $1,148
# GUARDIAN  Female   357    1900    $113,375
#           Male     188    1067     $71,298
#           Unisex     2      12      $1,421
# MED +     Female   407    2030    $122,460
#           Male     173    1005     $66,732
# ...

# %%
filtered_data = MED_SELECT_V6[MED_SELECT_V6['STATE_CODE'].isin(['QLD', 'VIC'])]

# %%
filtered_data
# Out:
#       CUSTOMER_ID    Company CARD_REG_DATE  GENDER  Age RGSTN_TYPE_IND  \
# 0      1000032547      MED +    2006-09-12  Female   36         Online
# 3      1000032550        GSK    2006-09-12    Male   43         Online
# 4      1000032551        GSK    2006-09-12    Male   42         Online
# 6      1000032553      CIPLA    2006-09-12  Female   34         Online
# 7      1000032554     APPOLO    2006-09-12    Male   34         Online
# ...           ...        ...           ...     ...  ...            ...
# 5052   1000037775   GUARDIAN    2008-04-10  Female   55         Online
# 5067   1000037790     APPOLO    2008-04-10    Male   35         Online
# 5087   1000037810       GENO    2008-05-06    Male   69         Online
# 5095   1000037818  DR.REDDYS    2008-05-06    Male   53         Online
# 5100   1000037823      CIPLA    2008-05-06  Female   72         Online
#
#      STATE_CODE  NO_OF_TRIPS            TOWN CONTACT_PREF  Spent amount  \
# ...

# %%
MED_AGG4=filtered_data.groupby(['STATE_CODE','Company'], as_index=True).agg(TOTAL_SPENT=('Spent amount','sum'))
MED_AGG5=MED_AGG4[MED_AGG4['TOTAL_SPENT']>=20000]
MED_AGG5['TOTAL_SPENT']=MED_AGG5['TOTAL_SPENT'].apply(lambda x: f"${x:,.0f}")
MED_AGG5
# Out:
# <ipython-input-115-6816bf1a05a1>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   MED_AGG5['TOTAL_SPENT']=MED_AGG5['TOTAL_SPENT'].apply(lambda x: f"${x:,.0f}")
#                      TOTAL_SPENT
# STATE_CODE Company
# QLD        APPOLO        $51,824
#            CIPLA         $53,112
#            DR.REDDYS     $57,667
#            GENO          $37,227
#            GSK           $57,655
#            GUARDIAN      $50,946
#            MED +         $49,955
#            RANBAXY       $44,911
#            RELEGARE      $55,585
# VIC        APPOLO        $26,079
#            CIPLA         $22,912
#            DR.REDDYS     $21,665
#            GSK           $22,302
#            GUARDIAN      $28,447
#            MED +         $24,854

# %%
MED_AGG6=MED_SELECT_V6.groupby(['Company','GENDER','CUSTOMER_SEGMENT','AGE_BUCKET'], as_index=True).agg(COUNT_OF_CUSTOMER_ID=('CUSTOMER_ID', 'count'), SUM_OF_TRIPS=('NO_OF_TRIPS','sum'),SUM_OF_SPENT=('Spent amount','sum'))
MED_AGG6['SUM_OF_SPENT']=MED_AGG6['SUM_OF_SPENT'].apply(lambda x: f"${x:,.0f}")
MED_AGG6['COUNT_OF_CUSTOMER_ID']=MED_AGG6['COUNT_OF_CUSTOMER_ID'].apply(lambda x: f"{x:,.0f}")
MED_AGG6['SUM_OF_TRIPS']=MED_AGG6['SUM_OF_TRIPS'].apply(lambda x: f"{x:,.0f}")
MED_AGG6
# Out:
#                                               COUNT_OF_CUSTOMER_ID  \
# Company  GENDER CUSTOMER_SEGMENT AGE_BUCKET
# APPOLO   Female NON-PREMIER      30 to 50                       98
#                                  51 to 70                       93
#                                  70+                            83
#                                  Less than 30                    2
#                 PREMIER          30 to 50                       54
# ...                                                            ...
# RELEGARE Male   PREMIER          30 to 50                       21
#                                  51 to 70                       32
#          Unisex NON-PREMIER      30 to 50                        1
#                                  51 to 70                        4
#                                  70+                             1
#
#                                               SUM_OF_TRIPS SUM_OF_SPENT
# Company  GENDER CUSTOMER_SEGMENT AGE_BUCKET
# ...

# %%
Blank_CONTACT_PREF=MED_SELECT_V6['CONTACT_PREF'].isnull().sum()
Blank_CONTACT_PREF
# Out:
# 893

# %% [markdown]
# ### Task-5

# %%
import pandas as pd

# %%
File_path = r'C:\Users\SAMBIT KUMAR\Downloads\A5.ASSIGNMENTS-20240403T050442Z-001\A5.ASSIGNMENTS\PYTHON SESSION-2 ASSIGNMENTS.xlsx'
CUSTOMER_MONTHLY_SALES = pd.read_excel(File_path, sheet_name='CUSTOMER_MONTHLY_SALES')

# %%
CUSTOMER_MONTHLY_SALES
# Out:
#     CUSTOMER_ID    Company  JAN  FEB  MAR  APR  MAY  JUN  JUL  AUG  SEP  OCT  \
# 0    1000032547      MED +  317  877  794  219  635  617  777  803  524  120
# 1    1000032548  DR.REDDYS  178  133  193  879  638  752  476  316  100  222
# 2    1000032549   RELEGARE  294  649  105  124  357  518  831  164  115  690
# 3    1000032550        GSK  368  293  322  597  722  475  559  438  396  801
# 4    1000032551        GSK  490  843  850  559  656  850  137  500  606  170
# 5    1000032552     APPOLO  184  381  260  107  654  490  243  763  760  852
# 6    1000032553      CIPLA  176  164  281  221  338  349  162  657  625  318
# 7    1000032554     APPOLO  666  477  647  262  325  532  550  445  124  598
# 8    1000032555     APPOLO  367  590  248  715  563  181  696  228  591  426
# 9    1000032556      MED +  797  883  783  733  484  144  613  575  883  281
# 10   1000032557        GSK  655  275  128  234  234  838  515  291  481  648
# ...

# %%
CUSTOMER_MONTHLY_SALES['Q1']=CUSTOMER_MONTHLY_SALES[['JAN','FEB','MAR']].sum(axis=1)
CUSTOMER_MONTHLY_SALES['Q2']=CUSTOMER_MONTHLY_SALES[['APR','MAY','JUN']].sum(axis=1)
CUSTOMER_MONTHLY_SALES['Q3']=CUSTOMER_MONTHLY_SALES[['JUL','AUG','SEP']].sum(axis=1)
CUSTOMER_MONTHLY_SALES['Q4']=CUSTOMER_MONTHLY_SALES[['OCT','NOV','DEC']].sum(axis=1)

# %%
CUSTOMER_MONTHLY_SALES
# Out:
#     CUSTOMER_ID    Company  JAN  FEB  MAR  APR  MAY  JUN  JUL  AUG  SEP  OCT  \
# 0    1000032547      MED +  317  877  794  219  635  617  777  803  524  120
# 1    1000032548  DR.REDDYS  178  133  193  879  638  752  476  316  100  222
# 2    1000032549   RELEGARE  294  649  105  124  357  518  831  164  115  690
# 3    1000032550        GSK  368  293  322  597  722  475  559  438  396  801
# 4    1000032551        GSK  490  843  850  559  656  850  137  500  606  170
# 5    1000032552     APPOLO  184  381  260  107  654  490  243  763  760  852
# 6    1000032553      CIPLA  176  164  281  221  338  349  162  657  625  318
# 7    1000032554     APPOLO  666  477  647  262  325  532  550  445  124  598
# 8    1000032555     APPOLO  367  590  248  715  563  181  696  228  591  426
# 9    1000032556      MED +  797  883  783  733  484  144  613  575  883  281
# 10   1000032557        GSK  655  275  128  234  234  838  515  291  481  648
# ...

# %%
CUSTOMER_MONTHLY_SALES['TOTAL SALES']=CUSTOMER_MONTHLY_SALES[['Q1','Q2','Q3']].sum(axis=1)
CUSTOMER_MONTHLY_SALES
# Out:
#     CUSTOMER_ID    Company  JAN  FEB  MAR  APR  MAY  JUN  JUL  AUG  SEP  OCT  \
# 0    1000032547      MED +  317  877  794  219  635  617  777  803  524  120
# 1    1000032548  DR.REDDYS  178  133  193  879  638  752  476  316  100  222
# 2    1000032549   RELEGARE  294  649  105  124  357  518  831  164  115  690
# 3    1000032550        GSK  368  293  322  597  722  475  559  438  396  801
# 4    1000032551        GSK  490  843  850  559  656  850  137  500  606  170
# 5    1000032552     APPOLO  184  381  260  107  654  490  243  763  760  852
# 6    1000032553      CIPLA  176  164  281  221  338  349  162  657  625  318
# 7    1000032554     APPOLO  666  477  647  262  325  532  550  445  124  598
# 8    1000032555     APPOLO  367  590  248  715  563  181  696  228  591  426
# 9    1000032556      MED +  797  883  783  733  484  144  613  575  883  281
# 10   1000032557        GSK  655  275  128  234  234  838  515  291  481  648
# ...

# %%
CUSTOMER_MONTHLY_SALES['Q1 SALES PERCENTAGE']=(CUSTOMER_MONTHLY_SALES['Q1']/CUSTOMER_MONTHLY_SALES['TOTAL SALES'])*100
CUSTOMER_MONTHLY_SALES['Q1 SALES PERCENTAGE']=CUSTOMER_MONTHLY_SALES['Q1 SALES PERCENTAGE'].apply(lambda x: f"{x:,.0f}%")
CUSTOMER_MONTHLY_SALES['Q2 SALES PERCENTAGE']=(CUSTOMER_MONTHLY_SALES['Q2']/CUSTOMER_MONTHLY_SALES['TOTAL SALES'])*100
CUSTOMER_MONTHLY_SALES['Q2 SALES PERCENTAGE']=CUSTOMER_MONTHLY_SALES['Q2 SALES PERCENTAGE'].apply(lambda x: f"{x:,.0f}%")
CUSTOMER_MONTHLY_SALES['Q3 SALES PERCENTAGE']=(CUSTOMER_MONTHLY_SALES['Q3']/CUSTOMER_MONTHLY_SALES['TOTAL SALES'])*100
CUSTOMER_MONTHLY_SALES['Q3 SALES PERCENTAGE']=CUSTOMER_MONTHLY_SALES['Q3 SALES PERCENTAGE'].apply(lambda x: f"{x:,.0f}%")
CUSTOMER_MONTHLY_SALES['Q4 SALES PERCENTAGE']=(CUSTOMER_MONTHLY_SALES['Q4']/CUSTOMER_MONTHLY_SALES['TOTAL SALES'])*100
CUSTOMER_MONTHLY_SALES['Q4 SALES PERCENTAGE']=CUSTOMER_MONTHLY_SALES['Q4 SALES PERCENTAGE'].apply(lambda x: f"{x:,.0f}%")

# %%
CUSTOMER_MONTHLY_SALES
# Out:
#     CUSTOMER_ID    Company  JAN  FEB  MAR  APR  MAY  JUN  JUL  AUG  ...  DEC  \
# 0    1000032547      MED +  317  877  794  219  635  617  777  803  ...  290
# 1    1000032548  DR.REDDYS  178  133  193  879  638  752  476  316  ...  540
# 2    1000032549   RELEGARE  294  649  105  124  357  518  831  164  ...  232
# 3    1000032550        GSK  368  293  322  597  722  475  559  438  ...  885
# 4    1000032551        GSK  490  843  850  559  656  850  137  500  ...  601
# 5    1000032552     APPOLO  184  381  260  107  654  490  243  763  ...  660
# 6    1000032553      CIPLA  176  164  281  221  338  349  162  657  ...  690
# 7    1000032554     APPOLO  666  477  647  262  325  532  550  445  ...  178
# 8    1000032555     APPOLO  367  590  248  715  563  181  696  228  ...  661
# 9    1000032556      MED +  797  883  783  733  484  144  613  575  ...  365
# 10   1000032557        GSK  655  275  128  234  234  838  515  291  ...  180
# ...

# %% [markdown]
# ### Task-6

# %%
STU_MASTER = pd.read_excel(r'C:\Users\SAMBIT KUMAR\Downloads\A5.ASSIGNMENTS-20240403T050442Z-001\A5.ASSIGNMENTS\PYTHON SESSION-2 ASSIGNMENTS.xlsx', sheet_name='STU_MASTER')
STU_MASTER
# Out:
#             FULL NAME         CITY STATE       PHONE DATE OF JOINING  \
# 0          James Butt  New Orleans    LA  5046218927      2019-02-11
# 1          James Butt  New Orleans    LA  5046218927      2019-02-11
# 2          James Butt  New Orleans    LA  5046218927      2019-02-11
# 3          James Butt  New Orleans    LA  5046218927      2019-02-11
# 4          James Butt  New Orleans    LA  5046218927      2019-02-11
# ...               ...          ...   ...         ...             ...
# 3965  Chauncey Motley      Orlando    FL  4074134842      2020-09-02
# 3966  Chauncey Motley      Orlando    FL  4074134842      2020-09-02
# 3967  Chauncey Motley      Orlando    FL  4074134842      2020-09-02
# 3968  Chauncey Motley      Orlando    FL  4074134842      2020-09-02
# 3969  Chauncey Motley      Orlando    FL  4074134842      2020-09-02
#
#            COURSE ENVIRONMENT      TOOL    FEE
# 0     MINI MODULE      NORMAL     EXCEL  10000
# ...

# %%
def DISCOUNT(row):
    COURSE = row['COURSE']
    TOOL = row['TOOL']
    Fee = row['FEE']
    
    if COURSE == 'MPIDS':
        if TOOL == 'SAS' and Fee == 25000:
            return 20
        elif TOOL == 'POWER BI' and Fee == 19000:
            return 30
        elif TOOL == 'ADVANCED ANALYTICS' and Fee == 45000:
            return 10
        elif TOOL == 'MACHINE LEARNING' and Fee == 70000:
            return 20
    elif COURSE == 'ADA':
        if TOOL == 'SQL' and Fee == 15000:
            return 10
        elif TOOL == 'PYTHON' and Fee == 15000:
            return 10
        elif TOOL == 'SAS' and Fee == 25000:
            return 20
        elif TOOL == 'R' and Fee == 15000:
            return 10
        elif TOOL == 'ADVANCED ANALYTICS' and Fee == 45000:
            return 10
    elif COURSE == 'DSA' and TOOL == 'SAS' and Fee == 25000:
        return 10
    elif COURSE == 'MINI MODULE':
        if TOOL == 'TABLEAU' and Fee == 17000:
            return 10
        elif TOOL == 'POWER BI' and Fee == 19000:
            return 10
        
    return 0

STU_MASTER['DISCOUNT'] = STU_MASTER.apply(DISCOUNT, axis=1)

# %%
STU_MASTER
# Out:
#             FULL NAME         CITY STATE       PHONE DATE OF JOINING  \
# 0          James Butt  New Orleans    LA  5046218927      2019-02-11
# 1          James Butt  New Orleans    LA  5046218927      2019-02-11
# 2          James Butt  New Orleans    LA  5046218927      2019-02-11
# 3          James Butt  New Orleans    LA  5046218927      2019-02-11
# 4          James Butt  New Orleans    LA  5046218927      2019-02-11
# ...               ...          ...   ...         ...             ...
# 3965  Chauncey Motley      Orlando    FL  4074134842      2020-09-02
# 3966  Chauncey Motley      Orlando    FL  4074134842      2020-09-02
# 3967  Chauncey Motley      Orlando    FL  4074134842      2020-09-02
# 3968  Chauncey Motley      Orlando    FL  4074134842      2020-09-02
# 3969  Chauncey Motley      Orlando    FL  4074134842      2020-09-02
#
#            COURSE ENVIRONMENT      TOOL    FEE  DISCOUNT
# 0     MINI MODULE      NORMAL     EXCEL  10000         0
# ...

# %%
STU_MASTER['FINAL_FEE']=STU_MASTER['FEE']-(STU_MASTER['FEE']*STU_MASTER['DISCOUNT']/100)
STU_MASTER['DISCOUNT']=STU_MASTER['DISCOUNT'].apply(lambda x: f"{x:,.0f}%")
STU_MASTER['FINAL_FEE']=STU_MASTER['FINAL_FEE'].apply(lambda x: f"{x:,.0f}")
STU_MASTER
# Out:
#             FULL NAME         CITY STATE       PHONE DATE OF JOINING  \
# 0          James Butt  New Orleans    LA  5046218927      2019-02-11
# 1          James Butt  New Orleans    LA  5046218927      2019-02-11
# 2          James Butt  New Orleans    LA  5046218927      2019-02-11
# 3          James Butt  New Orleans    LA  5046218927      2019-02-11
# 4          James Butt  New Orleans    LA  5046218927      2019-02-11
# ...               ...          ...   ...         ...             ...
# 3965  Chauncey Motley      Orlando    FL  4074134842      2020-09-02
# 3966  Chauncey Motley      Orlando    FL  4074134842      2020-09-02
# 3967  Chauncey Motley      Orlando    FL  4074134842      2020-09-02
# 3968  Chauncey Motley      Orlando    FL  4074134842      2020-09-02
# 3969  Chauncey Motley      Orlando    FL  4074134842      2020-09-02
#
#            COURSE ENVIRONMENT      TOOL      FEE DISCOUNT FINAL_FEE
# 0     MINI MODULE      NORMAL     EXCEL  10000.0       0%    10,000
# ...

# %%
STU_MASTER['DISCOUNT']=STU_MASTER['DISCOUNT'].apply(lambda x: f"{x:,.0f}%")

# %%
CUSTOMER_MONTHLY_SALES = CUSTOMER_MONTHLY_SALES[['CUSTOMER_ID','Company','JAN','FEB','MAR','APR','MAY','JUN','JUL','AUG','SEP','OCT','NOV','DEC']]
CUSTOMER_MONTHLY_SALES
# Out:
#     CUSTOMER_ID    Company  JAN  FEB  MAR  APR  MAY  JUN  JUL  AUG  SEP  OCT  \
# 0    1000032547      MED +  317  877  794  219  635  617  777  803  524  120
# 1    1000032548  DR.REDDYS  178  133  193  879  638  752  476  316  100  222
# 2    1000032549   RELEGARE  294  649  105  124  357  518  831  164  115  690
# 3    1000032550        GSK  368  293  322  597  722  475  559  438  396  801
# 4    1000032551        GSK  490  843  850  559  656  850  137  500  606  170
# 5    1000032552     APPOLO  184  381  260  107  654  490  243  763  760  852
# 6    1000032553      CIPLA  176  164  281  221  338  349  162  657  625  318
# 7    1000032554     APPOLO  666  477  647  262  325  532  550  445  124  598
# 8    1000032555     APPOLO  367  590  248  715  563  181  696  228  591  426
# 9    1000032556      MED +  797  883  783  733  484  144  613  575  883  281
# 10   1000032557        GSK  655  275  128  234  234  838  515  291  481  648
# ...

# %%
melted_df = CUSTOMER_MONTHLY_SALES.melt(id_vars=['CUSTOMER_ID', 'Company'], var_name=['MONTHS'], value_name='SALES')
melted_df
# Out:
#      CUSTOMER_ID    Company MONTHS  SALES
# 0     1000032547      MED +    JAN    317
# 1     1000032548  DR.REDDYS    JAN    178
# 2     1000032549   RELEGARE    JAN    294
# 3     1000032550        GSK    JAN    368
# 4     1000032551        GSK    JAN    490
# ..           ...        ...    ...    ...
# 355   1000032572        GSK    DEC    437
# 356   1000032573       GENO    DEC    333
# 357   1000032574        GSK    DEC    597
# 358   1000032575      MED +    DEC    248
# 359   1000032576      CIPLA    DEC    591
#
# [360 rows x 4 columns]

# %% [markdown]
# ### TASK-8

# %%
med_data_yearly = pd.read_excel(r'C:\Users\SAMBIT KUMAR\Downloads\A5.ASSIGNMENTS-20240403T050442Z-001\A5.ASSIGNMENTS\PYTHON SESSION-2 ASSIGNMENTS.xlsx', sheet_name='med_data_yearly')
med_data_yearly
# Out:
#      CUSTOMER_ID Company  YEAR  SALES
# 0     1000032547    MED+  2010    317
# 1     1000032547    MED+  2011    877
# 2     1000032547    MED+  2012    794
# 3     1000032547    MED+  2013    219
# 4     1000032547    MED+  2014    635
# ..           ...     ...   ...    ...
# 139   1000032558    MED+  2017    184
# 140   1000032558    MED+  2018    614
# 141   1000032558    MED+  2019    187
# 142   1000032558    MED+  2020    506
# 143   1000032558    MED+  2021    803
#
# [144 rows x 4 columns]

# %%
pivot_df= med_data_yearly.pivot(index=['CUSTOMER_ID','Company'],columns='YEAR',values='SALES')
pivot_df
# Out:
# YEAR                   2010  2011  2012  2013  2014  2015  2016  2017  2018  \
# CUSTOMER_ID Company
# 1000032547  MED+        317   877   794   219   635   617   777   803   524
# 1000032548  DR.REDDYS   178   133   193   879   638   752   476   316   100
# 1000032549  RELEGARE    294   649   105   124   357   518   831   164   115
# 1000032550  GSK         368   293   322   597   722   475   559   438   396
# 1000032551  GSK         490   843   850   559   656   850   137   500   606
# 1000032552  APPOLO      184   381   260   107   654   490   243   763   760
# 1000032553  CIPLA       176   164   281   221   338   349   162   657   625
# 1000032554  APPOLO      666   477   647   262   325   532   550   445   124
# 1000032555  APPOLO      367   590   248   715   563   181   696   228   591
# 1000032556  MED+        797   883   783   733   484   144   613   575   883
# 1000032557  GSK         655   275   128   234   234   838   515   291   481
# ...
