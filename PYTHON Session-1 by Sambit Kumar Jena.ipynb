# %%
A=100
B=300

# %%
C=B%A

# %%
C
# Out:
# 0

# %%
A=100
B=200
C=100+200

# %%
C
# Out:
# 300

# %%
ROW_NUMBER=range(0,10)

# %%
type(ROW_NUMBER)
# Out:
# range

# %%
import pandas as pd
STU_MASTER=pd.DataFrame({'STU_ID':['PRAVEEN','SHARMILA','MONALISA','SHYAM','VIBHU'],
                        'AGE':[30,23,27,29,30],
                        'GENDER':['MALE','FEMALE','FEMALE','MALE','MALE'],
                        'EDUCATION':['BTECH','MTECH','MBA','BCA','MCA'],
                        'DOE':['01/02/2022','04/02/2022','05/02/2022','07/02/2022','09/02/2022'],
                        'COURSE':['MPIDS','DAS','MPIDS','ADA','MPIDS']})
print(STU_MASTER)
# Out:
#      STU_ID  AGE  GENDER EDUCATION         DOE COURSE
# 0   PRAVEEN   30    MALE     BTECH  01/02/2022  MPIDS
# 1  SHARMILA   23  FEMALE     MTECH  04/02/2022    DAS
# 2  MONALISA   27  FEMALE       MBA  05/02/2022  MPIDS
# 3     SHYAM   29    MALE       BCA  07/02/2022    ADA
# 4     VIBHU   30    MALE       MCA  09/02/2022  MPIDS

# %%
STU_MASTER.shape
# Out:
# (5, 6)

# %%
STU_MASTER.columns.values
# Out:
# array(['STU_ID', 'AGE', 'GENDER', 'EDUCATION', 'DOE', 'COURSE'],
#       dtype=object)

# %%
STU_MASTER.head(2)
# Out:
#      STU_ID  AGE  GENDER EDUCATION         DOE COURSE
# 0   PRAVEEN   30    MALE     BTECH  01/02/2022  MPIDS
# 1  SHARMILA   23  FEMALE     MTECH  04/02/2022    DAS

# %%
STU_MASTER.tail(2)
# Out:
#   STU_ID  AGE GENDER EDUCATION         DOE COURSE
# 3  SHYAM   29   MALE       BCA  07/02/2022    ADA
# 4  VIBHU   30   MALE       MCA  09/02/2022  MPIDS

# %%
STU_MASTER.describe()
# Out:
#              AGE
# count   5.000000
# mean   27.800000
# std     2.949576
# min    23.000000
# 25%    27.000000
# 50%    29.000000
# 75%    30.000000
# max    30.000000

# %%
A=100
B="AYASH"
type(A)
# Out:
# int

# %% [markdown]
# ### TASK-2 Q1

# %%
import pandas as pd

# %%
DATA={'CUSTOMER_ID':[1000032547,
1000032548,
1000032549,
1000032550,
1000032551,
1000032552,
1000032553,
1000032554,
1000032555,
1000032556,
1000032557,
1000032558,
1000032559,
1000032560,
1000032561,
1000032562,
1000032563,
1000032564,
1000032565,
1000032566,
1000032567,
],'CUSTOMER NAME':['Rick Hansen',
'Justin Ritter',
'Craig Reiter',
'Katherine Murray',
'Rick Hansen',
'Jim Mitchum',
'Toby Swindell',
'Mick Brown',
'Jane Waco',
'Joseph Holt',
'Greg Maxwell',
'Anthony Jacobs',
'Magdelene Morse',
'Vicky Freymann',
'Peter Fuller',
'Ben Peterman',
'Thomas Boland',
'Patrick Jones',
'Jim Sink',
'Ritsa Hightower',
'Ann Blume'
],'CUSTOMER_SSN':['RH-19495',
'JR-16210',
'CR-12730',
'KM-16375',
'RH-9495',
'',
'TS-21340',
'MB-18085',
'JW-15220',
'JH-15985',
'GM-14695',
'AJ-10780',
'MM-7260',
'VF-21715',
'PF-19120',
'BP-11185',
'TB-21175',
'PJ-18835',
'',
'RH-9555',
'AB-600'
],'CITY':['New York City',
'Wollongong',
'Brisbane',
'Berlin',
'Dakar',
'Sydney',
'Porirua',
'Hamilton',
'Sacramento',
'Concord',
'Alexandria',
'',
'Jizan',
'Toledo',
'Mudanjiang',
'Paris',
'Henderson',
'Prato',
'Townsville',
'Uvinza',
'Bytom'
],'MARKET':['US',
'APAC',
'APAC',
'EU',
'Africa',
'APAC',
'APAC',
'APAC',
'US',
'US',
'US',
'APAC',
'EMEA',
'LATAM',
'APAC',
'EU',
'US',
'EU',
'APAC',
'Africa',
'EMEA'
],'DOB':['15-09-1984',
'15-07-1974',
'01-04-1959',
'16-05-1978',
'16-12-1978',
'21-07-1987',
'07-11-1986',
'29-04-1987',
'04-03-1958',
'15-08-1952',
'26-12-1984',
'17-02-1956',
'11-04-1979',
'12-03-1985',
'',
'10-01-1952',
'10-07-1965',
'20-07-1948',
'30-09-1949',
'21-10-1948',
'31-05-1972'
],'TOWN':['Kyabram',
'Hawthorn East',
'Revesby',
'Willow Grove',
'mona vale',
'Rowville',
'MINNAMURRA',
'Lake Illawarra',
'Vermont South',
'Blackburn Nth',
'Rowville',
'Box Hill North',
'FOREST HILL',
'BERWICK',
'Buderim',
'',
'scarness',
'Kuluin',
'Menai',
'',
'BARRACK HEIGHTS'
] }

# %%
CUSTOMER_MASTER=pd.DataFrame(DATA)

# %%
CUSTOMER_MASTER
# Out:
#     CUSTOMER_ID     CUSTOMER NAME CUSTOMER_SSN           CITY  MARKET  \
# 0    1000032547       Rick Hansen     RH-19495  New York City      US
# 1    1000032548     Justin Ritter     JR-16210     Wollongong    APAC
# 2    1000032549      Craig Reiter     CR-12730       Brisbane    APAC
# 3    1000032550  Katherine Murray     KM-16375         Berlin      EU
# 4    1000032551       Rick Hansen      RH-9495          Dakar  Africa
# 5    1000032552       Jim Mitchum                      Sydney    APAC
# 6    1000032553     Toby Swindell     TS-21340        Porirua    APAC
# 7    1000032554        Mick Brown     MB-18085       Hamilton    APAC
# 8    1000032555         Jane Waco     JW-15220     Sacramento      US
# 9    1000032556       Joseph Holt     JH-15985        Concord      US
# 10   1000032557      Greg Maxwell     GM-14695     Alexandria      US
# 11   1000032558    Anthony Jacobs     AJ-10780                   APAC
# ...

# %% [markdown]
# ### TASK-2 Q2

# %%
CUSTOMER_MASTER.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   CUSTOMER_ID    21 non-null     int64
#  1   CUSTOMER NAME  21 non-null     object
#  2   CUSTOMER_SSN   21 non-null     object
#  3   CITY           21 non-null     object
#  4   MARKET         21 non-null     object
#  5   DOB            21 non-null     object
#  6   TOWN           21 non-null     object
# dtypes: int64(1), object(6)
# memory usage: 1.3+ KB

# %%
column_headers = CUSTOMER_MASTER.columns.tolist()
column_headers
# Out:
# ['CUSTOMER_ID',
#  'CUSTOMER NAME',
#  'CUSTOMER_SSN',
#  'CITY',
#  'MARKET',
#  'DOB',
#  'TOWN']

# %%
CUSTOMER_MASTER.head(3)
# Out:
#    CUSTOMER_ID  CUSTOMER NAME CUSTOMER_SSN           CITY MARKET         DOB  \
# 0   1000032547    Rick Hansen     RH-19495  New York City     US  15-09-1984
# 1   1000032548  Justin Ritter     JR-16210     Wollongong   APAC  15-07-1974
# 2   1000032549   Craig Reiter     CR-12730       Brisbane   APAC  01-04-1959
#
#             TOWN
# 0        Kyabram
# 1  Hawthorn East
# 2        Revesby

# %%
CUSTOMER_MASTER.tail(3)
# Out:
#     CUSTOMER_ID    CUSTOMER NAME CUSTOMER_SSN        CITY  MARKET         DOB  \
# 18   1000032565         Jim Sink               Townsville    APAC  30-09-1949
# 19   1000032566  Ritsa Hightower      RH-9555      Uvinza  Africa  21-10-1948
# 20   1000032567        Ann Blume       AB-600       Bytom    EMEA  31-05-1972
#
#                TOWN
# 18            Menai
# 19
# 20  BARRACK HEIGHTS

# %%
CUSTOMER_MASTER.dtypes
# Out:
# CUSTOMER_ID       int64
# CUSTOMER NAME    object
# CUSTOMER_SSN     object
# CITY             object
# MARKET           object
# DOB              object
# TOWN             object
# dtype: object

# %%
CUSTOMER_MASTER.isnull().sum().sum()
# Out:
# 0

# %%
CUSTOMER_MASTER['CUSTOMER_SSN'].isnull().sum()
# Out:
# 0

# %% [markdown]
# ### TASK-3 Q1

# %%
ACCOUNT_PERF_EXCEL = pd.read_excel('ACCOUNT_PERF_DATA.xlsx')
ACCOUNT_PERF_EXCEL
# Out:
#        Account_number      PORTFOLIO          SSN    Phone No.   \
# 0            38673575    CREDIT CARD  640-29-9264  405-775-9884
# 1            38673576  PERSONAL LOAN  375-37-8517  212-786-7533
# 2            38673577  PERSONAL LOAN  073-02-5563  385-775-0225
# 3            38673578       MORTGAGE  106-98-7919  216-984-8974
# 4            38673579    CREDIT CARD  753-07-4655  217-307-8597
# ...               ...            ...          ...           ...
# 24999        38698574    CREDIT CARD  112-98-5765  201-857-6904
# 25000        38698575  PERSONAL LOAN  507-57-2035  209-410-5762
# 25001        38698576       MORTGAGE  094-02-7375  212-698-6318
# 25002        38698577  PERSONAL LOAN  467-99-0614  212-525-5734
# 25003        38698578       MORTGAGE  191-86-1363  229-974-6770
#
#            Place Name      County            City State    Zip     Region  \
# 0             Bromide    Johnston         Bromide    OK  74530      South
# ...

# %%
ACCOUNT_PERF_CSV = pd.read_csv('ACCOUNT_PERF_DATA -CSV.csv')
ACCOUNT_PERF_CSV
# Out:
#        Account_number      PORTFOLIO          SSN    Phone No.   \
# 0            38673575    CREDIT CARD  640-29-9264  405-775-9884
# 1            38673576  PERSONAL LOAN  375-37-8517  212-786-7533
# 2            38673577  PERSONAL LOAN  073-02-5563  385-775-0225
# 3            38673578       MORTGAGE  106-98-7919  216-984-8974
# 4            38673579    CREDIT CARD  753-07-4655  217-307-8597
# ...               ...            ...          ...           ...
# 24999        38698574    CREDIT CARD  112-98-5765  201-857-6904
# 25000        38698575  PERSONAL LOAN  507-57-2035  209-410-5762
# 25001        38698576       MORTGAGE  094-02-7375  212-698-6318
# 25002        38698577  PERSONAL LOAN  467-99-0614  212-525-5734
# 25003        38698578       MORTGAGE  191-86-1363  229-974-6770
#
#            Place Name      County            City State    Zip     Region  \
# 0             Bromide    Johnston         Bromide    OK  74530      South
# ...

# %%
ACCOUNT_PERF_TXT = pd.read_csv('ACCOUNT_PERF_DATA _TXT.txt', delimiter='\t')
ACCOUNT_PERF_TXT
# Out:
#        Account_number      PORTFOLIO          SSN    Phone No.   \
# 0            38673575    CREDIT CARD  640-29-9264  405-775-9884
# 1            38673576  PERSONAL LOAN  375-37-8517  212-786-7533
# 2            38673577  PERSONAL LOAN  073-02-5563  385-775-0225
# 3            38673578       MORTGAGE  106-98-7919  216-984-8974
# 4            38673579    CREDIT CARD  753-07-4655  217-307-8597
# ...               ...            ...          ...           ...
# 24999        38698574    CREDIT CARD  112-98-5765  201-857-6904
# 25000        38698575  PERSONAL LOAN  507-57-2035  209-410-5762
# 25001        38698576       MORTGAGE  094-02-7375  212-698-6318
# 25002        38698577  PERSONAL LOAN  467-99-0614  212-525-5734
# 25003        38698578       MORTGAGE  191-86-1363  229-974-6770
#
#            Place Name      County            City State    Zip     Region  \
# 0             Bromide    Johnston         Bromide    OK  74530      South
# ...

# %% [markdown]
# ### TASK-3 Q2

# %%
selected_column=['Account_number','PORTFOLIO','SSN','Phone No. ','City','State','Account Open Date','Loan_amount','Origination_fico_score','Current_fico_score','Current_outstanding']
ACCOUNT_PERF_V1 = ACCOUNT_PERF_EXCEL[selected_column].copy()
ACCOUNT_PERF_V1
# Out:
#        Account_number      PORTFOLIO          SSN    Phone No.   \
# 0            38673575    CREDIT CARD  640-29-9264  405-775-9884
# 1            38673576  PERSONAL LOAN  375-37-8517  212-786-7533
# 2            38673577  PERSONAL LOAN  073-02-5563  385-775-0225
# 3            38673578       MORTGAGE  106-98-7919  216-984-8974
# 4            38673579    CREDIT CARD  753-07-4655  217-307-8597
# ...               ...            ...          ...           ...
# 24999        38698574    CREDIT CARD  112-98-5765  201-857-6904
# 25000        38698575  PERSONAL LOAN  507-57-2035  209-410-5762
# 25001        38698576       MORTGAGE  094-02-7375  212-698-6318
# 25002        38698577  PERSONAL LOAN  467-99-0614  212-525-5734
# 25003        38698578       MORTGAGE  191-86-1363  229-974-6770
#
#                  City State Account Open Date  Loan_amount  \
# 0             Bromide    OK        2018-03-13        40169
# 1      Reading Center    NY        2019-06-23       187055
# ...

# %% [markdown]
# ### TASK-3 Q3

# %%
ACCOUNT_PERF_V1.head(1000)
# Out:
#      Account_number      PORTFOLIO          SSN    Phone No.             City  \
# 0          38673575    CREDIT CARD  640-29-9264  405-775-9884         Bromide
# 1          38673576  PERSONAL LOAN  375-37-8517  212-786-7533  Reading Center
# 2          38673577  PERSONAL LOAN  073-02-5563  385-775-0225          Ibapah
# 3          38673578       MORTGAGE  106-98-7919  216-984-8974       Wickliffe
# 4          38673579    CREDIT CARD  753-07-4655  217-307-8597         Forrest
# ..              ...            ...          ...           ...             ...
# 995        38674570    CREDIT CARD  059-02-7412  225-732-1222     New Orleans
# 996        38674571    CREDIT CARD  274-17-5324  218-652-2488         Maynard
# 997        38674572       MORTGAGE  061-02-3181  229-491-7441      Bainbridge
# 998        38674573       MORTGAGE  063-02-8673  603-857-2424  Center Ossipee
# 999        38674574    CREDIT CARD  008-94-6199  205-655-3751     Robertsdale
#
# ...

# %% [markdown]
# # TASK-3 Q4

# %%
ACCOUNT_PERF_V1.dtypes
# Out:
# Account_number                     int64
# PORTFOLIO                         object
# SSN                               object
# Phone No.                         object
# City                              object
# State                             object
# Account Open Date         datetime64[ns]
# Loan_amount                        int64
# Origination_fico_score             int64
# Current_fico_score                 int64
# Current_outstanding              float64
# dtype: object

# %% [markdown]
# ### TASK-3 Q5

# %%
ACCOUNT_PERF_V1.select_dtypes(include='int64').columns.tolist()
# Out:
# ['Account_number',
#  'Loan_amount',
#  'Origination_fico_score',
#  'Current_fico_score']

# %%
ACCOUNT_PERF_V1.select_dtypes(include='float64').columns.tolist()
# Out:
# ['Current_outstanding']

# %% [markdown]
# ### TASK-3 Q6

# %%
ACCOUNT_PERF_V1.isnull().sum().sum()
# Out:
# 150

# %% [markdown]
# ### TASK-3 Q7

# %%
ACCOUNT_PERF_V1['SSN'].isnull().sum()
# Out:
# 0

# %% [markdown]
# ### TASK-3 Q8

# %%
ACCOUNT_PERF_EXCEL
# Out:
#        Account_number      PORTFOLIO          SSN    Phone No.   \
# 0            38673575    CREDIT CARD  640-29-9264  405-775-9884
# 1            38673576  PERSONAL LOAN  375-37-8517  212-786-7533
# 2            38673577  PERSONAL LOAN  073-02-5563  385-775-0225
# 3            38673578       MORTGAGE  106-98-7919  216-984-8974
# 4            38673579    CREDIT CARD  753-07-4655  217-307-8597
# ...               ...            ...          ...           ...
# 24999        38698574    CREDIT CARD  112-98-5765  201-857-6904
# 25000        38698575  PERSONAL LOAN  507-57-2035  209-410-5762
# 25001        38698576       MORTGAGE  094-02-7375  212-698-6318
# 25002        38698577  PERSONAL LOAN  467-99-0614  212-525-5734
# 25003        38698578       MORTGAGE  191-86-1363  229-974-6770
#
#            Place Name      County            City State    Zip     Region  \
# 0             Bromide    Johnston         Bromide    OK  74530      South
# ...

# %%
columns_to_drop = ['Place Name','County','City','Region','Loan_status','Origination_fico_score','Current_fico_score']
ACCOUNT_PERF_V2=ACCOUNT_PERF_EXCEL.drop(columns=columns_to_drop)
ACCOUNT_PERF_V2
# Out:
#        Account_number      PORTFOLIO          SSN    Phone No.  State    Zip  \
# 0            38673575    CREDIT CARD  640-29-9264  405-775-9884    OK  74530
# 1            38673576  PERSONAL LOAN  375-37-8517  212-786-7533    NY  14876
# 2            38673577  PERSONAL LOAN  073-02-5563  385-775-0225    UT  84034
# 3            38673578       MORTGAGE  106-98-7919  216-984-8974    OH  44092
# 4            38673579    CREDIT CARD  753-07-4655  217-307-8597    IL  61741
# ...               ...            ...          ...           ...   ...    ...
# 24999        38698574    CREDIT CARD  112-98-5765  201-857-6904    NJ   8090
# 25000        38698575  PERSONAL LOAN  507-57-2035  209-410-5762    CA  95255
# 25001        38698576       MORTGAGE  094-02-7375  212-698-6318    NY  13225
# 25002        38698577  PERSONAL LOAN  467-99-0614  212-525-5734    NY  11797
# 25003        38698578       MORTGAGE  191-86-1363  229-974-6770    GA  30813
#
# ...

# %% [markdown]
# ### TASK-3 Q9

# %%
# Export DataFrame to Excel
ACCOUNT_PERF_V1.to_excel('ACCOUNT_PERF_V1.xlsx', index=False)

# %%
# Export DataFrame to Text with comma delimiter
ACCOUNT_PERF_V1.to_csv('ACCOUNT_PERF_V1.txt', index=False, sep=',')

# %%
# Export DataFrame to CSV
ACCOUNT_PERF_V1.to_csv('ACCOUNT_PERF_V1.csv', index=False)
